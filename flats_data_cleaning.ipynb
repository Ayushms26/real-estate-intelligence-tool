# %%
import numpy as np
import pandas as pd

# %%
# when we print big data so middel rows get hidden
# so for this ----->

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/content/flats - flats.csv')

# %%
df.shape
# Out:
# (3028, 20)

# %%
df.head()
# Out:
#                      property_name  \
# 0     2 BHK Flat in Krishna Colony
# 1        2 BHK Flat in Ashok Vihar
# 2              2 BHK Flat in Sohna
# 3  2 BHK Flat in Sector 61 Gurgaon
# 4  2 BHK Flat in Sector 92 Gurgaon
#
#                                                 link                 society  \
# 0  https://www.99acres.com/2-bhk-bedroom-apartmen...  maa bhagwati residency
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...            Apna Enclave
# 2  https://www.99acres.com/2-bhk-bedroom-apartmen...  Tulsiani Easy in Homes
# 3  https://www.99acres.com/2-bhk-bedroom-apartmen...     Smart World Orchard
# 4  https://www.99acres.com/2-bhk-bedroom-apartmen...        Parkwood Westend
#
#         price             area                            areaWithType  \
# 0      45 Lac   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)
# 1      50 Lac   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)
# ...

# %%
df.iloc[[2994,2995,2996,2997,2998,2999,3000,3001,3002,3003,3004]]
# Out:
#                                         property_name  \
# 2994                        4 BHK Flat in DLF Phase 4
# 2995                  3 BHK Flat in Sector 9A Gurgaon
# 2996                 3 BHK Flat in Sector 37C Gurgaon
# 2997                       3 BHK Flat in Adarsh Nagar
# 2998                      3 BHK Flat in Rajendra Park
# 2999                  2 BHK Flat in Sector 79 Gurgaon
# 3000                 3 BHK Flat in Sector 37C Gurgaon
# 3001                  3 BHK Flat in Sector 78 Gurgaon
# 3002                 3 BHK Flat in Sector 88A Gurgaon
# 3003  2 BHK Flat in Godrej Aria , sector 79 , Gurgaon
# 3004                        4 BHK Flat in DLF Phase 4
#
#                                                    link  \
# 2994  https://www.99acres.com/4-bhk-bedroom-apartmen...
# 2995  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 2996  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 2997  https://www.99acres.com/3-bhk-bedroom-apartmen...
# ...

# %%
df.drop(index=[2994, 2995, 2996, 2997, 2998, 2999, 3000, 3001, 3002, 3003, 3004], inplace=True)

# %%
df.shape
# Out:
# (3028, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3017 entries, 0 to 3027
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3017 non-null   object
#  1   link             3017 non-null   object
#  2   society          3016 non-null   object
#  3   price            3007 non-null   object
#  4   area             3004 non-null   object
#  5   areaWithType     3008 non-null   object
#  6   bedRoom          3008 non-null   object
#  7   bathroom         3008 non-null   object
#  8   balcony          3008 non-null   object
#  9   additionalRoom   1695 non-null   object
#  10  address          3002 non-null   object
#  11  floorNum         3006 non-null   object
#  12  facing           2128 non-null   object
#  13  agePossession    3007 non-null   object
#  14  nearbyLocations  2913 non-null   object
#  15  description      3008 non-null   object
#  16  furnishDetails   2204 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Remove unwanted Columns

df = df.drop(columns=['link','property_id'])

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#               area                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# rename columns
df.rename(columns={'area':'price_per_sqft'},inplace=True)

# %%
df['society'].value_counts()
# Out:
# society
# SS The Leaf3.8 ★                                     73
# Tulip Violet4.3 ★                                    40
# Shapoorji Pallonji Joyville Gurugram4.0 ★            39
# Signature Global Park4.0 ★                           36
# Shree Vardhman Victoria3.8 ★                         35
# Tulip Violet4.2 ★                                    33
# Smart World Gems                                     32
# Emaar MGF Emerald Floors Premier3.8 ★                32
# Smart World Orchard                                  32
# DLF The Ultima4.0 ★                                  31
# Paras Dews                                           31
# DLF Regal Gardens3.9 ★                               30
# Shree Vardhman Flora3.8 ★                            29
# M3M Woodshire4.0 ★                                   29
# La Vida by Tata Housing                              28
# Signature Global Solera3.7 ★                         28
# Godrej Nature Plus                                   27
# ...

# %%
df['society'].value_counts().shape
# Out:
# (638,)

# %% [markdown]
# # We cant work with that much society --> so reduce it

# %%
import re

# %%
# first removing that rating and star mark from rating

df['society'] = df['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★','',str(name)).strip()).str.lower()

# %%
df['society'].shape
# Out:
# (3017,)

# %%
df.head(2)
# Out:
#                   property_name                 society   price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency  45 Lac
# 1     2 BHK Flat in Ashok Vihar            apna enclave  50 Lac
#
#    price_per_sqft                    areaWithType     bedRoom     bathroom  \
# 0  ₹ 5,000/sq.ft.  Carpet area: 900 (83.61 sq.m.)  2 Bedrooms  2 Bathrooms
# 1  ₹ 7,692/sq.ft.  Carpet area: 650 (60.39 sq.m.)  2 Bedrooms  2 Bathrooms
#
#      balcony additionalRoom                             address  \
# 0  1 Balcony            NaN    Krishna Colony, Gurgaon, Haryana
# 1  1 Balcony            NaN  46b, Ashok Vihar, Gurgaon, Haryana
#
#             floorNum facing    agePossession  \
# 0  4th   of 4 Floors   West  1 to 5 Year Old
# 1  1st   of 3 Floors   West     10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
# ...

# %%
df['price'].value_counts()
# Out:
# price
# 1.25 Crore          79
# 1.1 Crore           61
# 1.4 Crore           60
# 1.2 Crore           59
# 1.5 Crore           59
# 1.3 Crore           57
# 90 Lac              57
# 95 Lac              53
# 2 Crore             51
# 1.75 Crore          47
# 1 Crore             46
# 1.6 Crore           43
# 1.35 Crore          41
# 1.55 Crore          40
# 1.9 Crore           40
# 1.65 Crore          38
# 75 Lac              38
# 1.7 Crore           37
# 1.8 Crore           37
# 80 Lac              36
# 2.2 Crore           34
# 50 Lac              33
# 1.15 Crore          33
# 85 Lac              31
# 1.45 Crore          31
# 1.05 Crore          30
# 40 Lac              29
# 60 Lac              29
# 2.5 Crore           29
# 45 Lac              26
# 2.1 Crore           26
# 65 Lac              25
# 2.35 Crore          23
# 1.85 Crore          23
# 35 Lac              23
# 3 Crore             22
# 70 Lac              21
# 55 Lac              20
# 2.25 Crore          20
# ...

# %%
df['price'] = df['price'][df['price'] != 'Price on Request']

# %%
df.head(2)
# Out:
#                   property_name                 society   price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency  45 Lac
# 1     2 BHK Flat in Ashok Vihar            apna enclave  50 Lac
#
#    price_per_sqft                    areaWithType     bedRoom     bathroom  \
# 0  ₹ 5,000/sq.ft.  Carpet area: 900 (83.61 sq.m.)  2 Bedrooms  2 Bathrooms
# 1  ₹ 7,692/sq.ft.  Carpet area: 650 (60.39 sq.m.)  2 Bedrooms  2 Bathrooms
#
#      balcony additionalRoom                             address  \
# 0  1 Balcony            NaN    Krishna Colony, Gurgaon, Haryana
# 1  1 Balcony            NaN  46b, Ashok Vihar, Gurgaon, Haryana
#
#             floorNum facing    agePossession  \
# 0  4th   of 4 Floors   West  1 to 5 Year Old
# 1  1st   of 3 Floors   West     10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3017 entries, 0 to 3027
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3017 non-null   object
#  1   society          3017 non-null   object
#  2   price            2996 non-null   object
#  3   price_per_sqft   3004 non-null   object
#  4   areaWithType     3008 non-null   object
#  5   bedRoom          3008 non-null   object
#  6   bathroom         3008 non-null   object
#  7   balcony          3008 non-null   object
#  8   additionalRoom   1695 non-null   object
#  9   address          3002 non-null   object
#  10  floorNum         3006 non-null   object
#  11  facing           2128 non-null   object
#  12  agePossession    3007 non-null   object
#  13  nearbyLocations  2913 non-null   object
#  14  description      3008 non-null   object
#  15  furnishDetails   2204 non-null   object
#  16  features         2595 non-null   object
# ...

# %%
df['price'].isna().sum()
# Out:
# np.int64(21)

# %%
df.dropna(subset=['price'], inplace=True)

# %%
df['price'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Now convert all price into 'Crore' scale

# %%
def price(x):
    if isinstance(x, float) or pd.isna(x):
        return x
    parts = x.split(' ')
    if len(parts) < 2:
        return np.nan  # or handle it differently
    if parts[1] == 'Lac':
        return round(float(parts[0]) / 100, 2)
    else:
        return round(float(parts[0]), 2)

df['price'] = df['price'].apply(price)

# %%
df.head(2)
# Out:
#                   property_name                 society  price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1     2 BHK Flat in Ashok Vihar            apna enclave   0.50
#
#    price_per_sqft                    areaWithType     bedRoom     bathroom  \
# 0  ₹ 5,000/sq.ft.  Carpet area: 900 (83.61 sq.m.)  2 Bedrooms  2 Bathrooms
# 1  ₹ 7,692/sq.ft.  Carpet area: 650 (60.39 sq.m.)  2 Bedrooms  2 Bathrooms
#
#      balcony additionalRoom                             address  \
# 0  1 Balcony            NaN    Krishna Colony, Gurgaon, Haryana
# 1  1 Balcony            NaN  46b, Ashok Vihar, Gurgaon, Haryana
#
#             floorNum facing    agePossession  \
# 0  4th   of 4 Floors   West  1 to 5 Year Old
# 1  1st   of 3 Floors   West     10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
# ...

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹','').str.replace(',','').str.strip().astype('float')

# %%
df['price_per_sqft']
# Out:
# 0         5000.0
# 1         7692.0
# 2         6722.0
# 3        12250.0
# 4         5204.0
# 5         6269.0
# 6        13333.0
# 7         7860.0
# 8         8148.0
# 9        16885.0
# 10        9767.0
# 11        5587.0
# 12        6940.0
# 13        6859.0
# 14        5384.0
# 15       16859.0
# 16       14084.0
# 17       11475.0
# 19       10476.0
# 20        9156.0
# 21        8604.0
# 22        7796.0
# 23        9135.0
# 24       12855.0
# 26        7910.0
# 27       18331.0
# 28       24300.0
# 29        5600.0
# 30       12784.0
# 31       26936.0
# 32       10156.0
# 33        7194.0
# 34        6538.0
# 35        5769.0
# 36        6950.0
# 37        8866.0
# 38        5403.0
# 39        5714.0
# 40       15151.0
# 41        6200.0
# 42       16000.0
# 43        6378.0
# 44        3571.0
# 45        7846.0
# 46        7297.0
# 47        7581.0
# 48       10005.0
# 49       10714.0
# 50       16969.0
# 51       14545.0
# 52        5424.0
# 53        7410.0
# ...

# %%
df.head(
    2
)
# Out:
#                   property_name                 society  price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1     2 BHK Flat in Ashok Vihar            apna enclave   0.50
#
#    price_per_sqft                    areaWithType     bedRoom     bathroom  \
# 0          5000.0  Carpet area: 900 (83.61 sq.m.)  2 Bedrooms  2 Bathrooms
# 1          7692.0  Carpet area: 650 (60.39 sq.m.)  2 Bedrooms  2 Bathrooms
#
#      balcony additionalRoom                             address  \
# 0  1 Balcony            NaN    Krishna Colony, Gurgaon, Haryana
# 1  1 Balcony            NaN  46b, Ashok Vihar, Gurgaon, Haryana
#
#             floorNum facing    agePossession  \
# 0  4th   of 4 Floors   West  1 to 5 Year Old
# 1  1st   of 3 Floors   West     10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
# ...

# %%
df['bedRoom'].value_counts()
# Out:
# bedRoom
# 3 Bedrooms    1437
# 2 Bedrooms     943
# 4 Bedrooms     477
# 1 Bedroom      104
# 5 Bedrooms      31
# 6 Bedrooms       3
# Name: count, dtype: int64

# %%
df['bedRoom'].str.split(' ').str.get(0).astype('int')
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
# 5       2
# 6       3
# 7       3
# 8       2
# 9       3
# 10      2
# 11      2
# 12      3
# 13      2
# 14      2
# 15      4
# 16      1
# 17      2
# 19      3
# 20      2
# 21      3
# 22      2
# 23      3
# 24      3
# 26      2
# 27      3
# 28      3
# 29      2
# 30      2
# 31      2
# 32      4
# 33      2
# 34      3
# 35      2
# 36      2
# 37      3
# 38      2
# 39      2
# 40      3
# 41      2
# 42      3
# 43      4
# 44      2
# 45      3
# 46      4
# 47      2
# 48      3
# 49      3
# 50      3
# 51      2
# 52      2
# 53      3
# 54      2
# 55      4
# 56      1
# 57      1
# 58      3
# 59      2
# 60      2
# 61      2
# 62      4
# 63      2
# 64      3
# 65      4
# 66      3
# 67      3
# 68      2
# 69      2
# 70      2
# 71      3
# 72      2
# 73      2
# 74      2
# 75      3
# 76      2
# 77      2
# 78      3
# 79      3
# 80      3
# 81      3
# 82      2
# 83      5
# 84      2
# ...

# %%
df['bathroom'].value_counts()
# Out:
# bathroom
# 2 Bathrooms    1042
# 3 Bathrooms     989
# 4 Bathrooms     636
# 5 Bathrooms     169
# 1 Bathroom      112
# 6 Bathrooms      42
# 7 Bathrooms       5
# Name: count, dtype: int64

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 3 Balconies     973
# 3+ Balconies    861
# 2 Balconies     749
# 1 Balcony       315
# No Balcony       97
# Name: count, dtype: int64

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.replace('No','0')

# %%
df.head(2)
# Out:
#                   property_name                 society  price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1     2 BHK Flat in Ashok Vihar            apna enclave   0.50
#
#    price_per_sqft                    areaWithType     bedRoom  bathroom  \
# 0          5000.0  Carpet area: 900 (83.61 sq.m.)  2 Bedrooms         2
# 1          7692.0  Carpet area: 650 (60.39 sq.m.)  2 Bedrooms         2
#
#   balcony additionalRoom                             address  \
# 0       1            NaN    Krishna Colony, Gurgaon, Haryana
# 1       1            NaN  46b, Ashok Vihar, Gurgaon, Haryana
#
#             floorNum facing    agePossession  \
# 0  4th   of 4 Floors   West  1 to 5 Year Old
# 1  1st   of 3 Floors   West     10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
#                                          description  \
# ...

# %%
df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# Servant Room                                     629
# Study Room                                       232
# Others                                           179
# Pooja Room                                       132
# Study Room,Servant Room                           81
# Store Room                                        76
# Pooja Room,Servant Room                           60
# Servant Room,Others                               52
# Servant Room,Pooja Room                           30
# Study Room,Others                                 27
# Pooja Room,Study Room,Servant Room,Others         25
# Pooja Room,Study Room,Servant Room                24
# Servant Room,Store Room                           19
# Pooja Room,Study Room                             13
# Pooja Room,Study Room,Servant Room,Store Room     12
# Servant Room,Study Room                            8
# Study Room,Pooja Room                              8
# ...

# %%
df['additionalRoom'].isna().sum()
# Out:
# np.int64(1303)

# %%
df['additionalRoom'].fillna('not available',inplace=True)
# Out:
# <ipython-input-57-37c81a970354>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['additionalRoom'].fillna('not available',inplace=True)

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df['floorNum']
# Out:
# 0              4th   of 4 Floors
# 1              1st   of 3 Floors
# 2            12nd   of 14 Floors
# 3              2nd   of 4 Floors
# 4              5th   of 8 Floors
# 5              3rd   of 3 Floors
# 6             5th   of 25 Floors
# 7            14th   of 27 Floors
# 8              2nd   of 3 Floors
# 9            31st   of 40 Floors
# 10             1st   of 4 Floors
# 11            4th   of 13 Floors
# 12            4th   of 15 Floors
# 13            3rd   of 20 Floors
# 14           13rd   of 13 Floors
# 15           25th   of 25 Floors
# 16            Ground of 1 Floors
# 17           Ground of 14 Floors
# 19           12nd   of 13 Floors
# 20             4th   of 4 Floors
# 21           11st   of 22 Floors
# 22             4th   of 4 Floors
# 23           Ground of 14 Floors
# 24           10th   of 25 Floors
# 26             3rd   of 3 Floors
# 27           20th   of 20 Floors
# 28            5th   of 17 Floors
# 29            4th   of 12 Floors
# ...

# %%
df['floorNum'] = df['floorNum'].str.split(' ').str.get(0).replace('Ground','0').str.replace('Basement','-1').str.replace('Lower','0').str.extract(r'(\d+)')

# %%
df.head(2)
# Out:
#                   property_name                 society  price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1     2 BHK Flat in Ashok Vihar            apna enclave   0.50
#
#    price_per_sqft                    areaWithType     bedRoom  bathroom  \
# 0          5000.0  Carpet area: 900 (83.61 sq.m.)  2 Bedrooms         2
# 1          7692.0  Carpet area: 650 (60.39 sq.m.)  2 Bedrooms         2
#
#   balcony additionalRoom                             address floorNum facing  \
# 0       1  not available    Krishna Colony, Gurgaon, Haryana        4   West
# 1       1  not available  46b, Ashok Vihar, Gurgaon, Haryana        1   West
#
#      agePossession                                    nearbyLocations  \
# 0  1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1     10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
#                                          description  \
# ...

# %%
df.shape
# Out:
# (2995, 18)

# %%
df[df['floorNum'].isnull()]
# Out:
#                                 property_name             society  price  \
# 181   3 BHK Flat in Dwarka Expressway Gurgaon  experion heartsong   1.08
# 2767          2 BHK Flat in Sector 78 Gurgaon                 nan   0.60
#
#       price_per_sqft                        areaWithType     bedRoom  \
# 181           6150.0  Built Up area: 1758 (163.32 sq.m.)  3 Bedrooms
# 2767          3692.0  Built Up area: 1625 (150.97 sq.m.)  2 Bedrooms
#
#       bathroom balcony additionalRoom  \
# 181          3       0  not available
# 2767         2       0  not available
#
#                                                 address floorNum facing  \
# 181   604, Tower B-3, 6th Floor,Sector 108, Dwarka E...      NaN    NaN
# 2767       Gurgaon, Sector 78 Gurgaon, Gurgaon, Haryana      NaN    NaN
#
#            agePossession nearbyLocations  \
# 181   Under Construction             NaN
# 2767  Under Construction             NaN
#
# ...

# %%
# facing
df['facing'].value_counts()
# Out:
# facing
# North-East    505
# East          489
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: count, dtype: int64

# %%
df['facing'].isnull().sum()
# Out:
# np.int64(873)

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# <ipython-input-68-e6ba103970bd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA',inplace=True)

# %%
df['facing'].value_counts()
# Out:
# facing
# NA            873
# North-East    505
# East          489
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: count, dtype: int64

# %%
df.insert(loc=4,column='area',value=round((df['price']*10000000)/df['price_per_sqft']))

# %%
df.head(2)
# Out:
#                   property_name                 society  price  \
# 0  2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1     2 BHK Flat in Ashok Vihar            apna enclave   0.50
#
#    price_per_sqft   area                    areaWithType     bedRoom  \
# 0          5000.0  900.0  Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1          7692.0  650.0  Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
#
#    bathroom balcony additionalRoom                             address  \
# 0         2       1  not available    Krishna Colony, Gurgaon, Haryana
# 1         2       1  not available  46b, Ashok Vihar, Gurgaon, Haryana
#
#   floorNum facing    agePossession  \
# 0        4   West  1 to 5 Year Old
# 1        1   West     10+ Year Old
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
#
#                                          description  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2995 entries, 0 to 3027
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2995 non-null   object
#  1   society          2995 non-null   object
#  2   price            2995 non-null   float64
#  3   price_per_sqft   2995 non-null   float64
#  4   area             2995 non-null   float64
#  5   areaWithType     2995 non-null   object
#  6   bedRoom          2995 non-null   object
#  7   bathroom         2995 non-null   int64
#  8   balcony          2995 non-null   object
#  9   additionalRoom   2995 non-null   object
#  10  address          2989 non-null   object
#  11  floorNum         2993 non-null   object
#  12  facing           2995 non-null   object
#  13  agePossession    2994 non-null   object
#  14  nearbyLocations  2904 non-null   object
#  15  description      2995 non-null   object
# ...

# %%
df.shape
# Out:
# (2995, 19)

# %%
df.to_csv('flats_cleaned.csv', index=False)
